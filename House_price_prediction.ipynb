# %% [markdown]
# Step 1: Loading Python Package

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Eploratory DATA Analysis (EDA)

# %% [markdown]
# Step 2: Loading house_price_test and house_price_train DATA and storing the in data_test and data _train variable respectively

# %%
data_test = pd.read_csv('house_price_test.csv')
data_train = pd.read_csv('house_price_train.csv')

# %% [markdown]
# step 3: Checking CSV File info overview

# %%
data_test.info()
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    12 non-null     int64
#  1   Rooms   12 non-null     int64
#  2   Price   12 non-null     int64
# dtypes: int64(3)
# memory usage: 416.0 bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    35 non-null     int64
#  1   Rooms   35 non-null     int64
#  2   Price   35 non-null     int64
# dtypes: int64(3)
# memory usage: 968.0 bytes

# %% [markdown]
# O/P: It shows that both data_test contain 3 columns and 12 rows and have non-null values and integer type data of size 64 bit whereas data_train contain 3 columns and 35 rows and have non-null values and integer type data of size 64 bit

# %% [markdown]
# step 7: Now concating the two DataFrame data_test and data_train

# %%
data = pd.concat([data_test,data_train], axis=0)

# %% [markdown]
# O/P : It will give a DataFrame by concating the two given dataframe, axis=0 means it will concate by row values.

# %%
data
# Out:
#     Area  Rooms   Price
# 0   2609      4  499998
# 1   2238      3  329900
# 2   4478      5  699900
# 3   1962      4  259900
# 4   1600      3  329900
# 5   1268      3  259900
# 6   3031      4  599000
# 7   1664      2  368500
# 8   1767      3  252900
# 9   3137      3  579900
# 10  4215      4  549000
# 11  1888      2  255000
# 0   2637      3  299900
# 1   2132      4  345000
# 2   1985      4  299900
# 3   1416      2  232000
# 4   2567      4  314000
# 5   2162      4  287000
# 6   1494      3  242500
# 7   2000      3  347000
# 8   2040      4  314900
# 9   1000      1  169900
# 10  1239      3  229900
# 11  3000      4  539900
# 12  2104      3  399900
# 13  1437      3  249900
# 14  1839      2  349900
# 15  1852      4  299900
# 16  1236      3  199900
# 17  1100      3  249900
# 18  1380      3  212000
# 19  1940      4  239999
# 20  1458      3  464500
# 21  1427      3  198999
# 22   852      2  179900
# 23  1604      3  242900
# 24  1811      4  285900
# ...

# %% [markdown]
# Now resting the index of our concated DataFrame and droping the previous Index

# %%
data.reset_index(drop=True)
# Out:
#     Area  Rooms   Price
# 0   2609      4  499998
# 1   2238      3  329900
# 2   4478      5  699900
# 3   1962      4  259900
# 4   1600      3  329900
# 5   1268      3  259900
# 6   3031      4  599000
# 7   1664      2  368500
# 8   1767      3  252900
# 9   3137      3  579900
# 10  4215      4  549000
# 11  1888      2  255000
# 12  2637      3  299900
# 13  2132      4  345000
# 14  1985      4  299900
# 15  1416      2  232000
# 16  2567      4  314000
# 17  2162      4  287000
# 18  1494      3  242500
# 19  2000      3  347000
# 20  2040      4  314900
# 21  1000      1  169900
# 22  1239      3  229900
# 23  3000      4  539900
# 24  2104      3  399900
# 25  1437      3  249900
# 26  1839      2  349900
# 27  1852      4  299900
# 28  1236      3  199900
# 29  1100      3  249900
# 30  1380      3  212000
# 31  1940      4  239999
# 32  1458      3  464500
# 33  1427      3  198999
# 34   852      2  179900
# 35  1604      3  242900
# 36  1811      4  285900
# ...

# %% [markdown]
# Now checking the DataFrame info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    47 non-null     int64
#  1   Rooms   47 non-null     int64
#  2   Price   47 non-null     int64
# dtypes: int64(3)
# memory usage: 1.5 KB

# %% [markdown]
# O/P : It shows that our DataFrame contains 3 columns i.e Area, Rooms and Price each having 47 Rows with non-null values and Integer type Data of size 64bit.

# %%
data.dtypes
# Out:
# Area     int64
# Rooms    int64
# Price    int64
# dtype: object

# %% [markdown]
# O/P : It just give the type of Data present in our DataFrame.

# %% [markdown]
# Now checking if there is any null-value present in our DataFrame.

# %%
data.isna().apply(pd.value_counts).T
# Out:
#        False
# Area      47
# Rooms     47
# Price     47

# %% [markdown]
# O/P : It shows that there ins no null-value present in our DataFrame as there is no True column printed.

# %%
data.head()
# Out:
#    Area  Rooms   Price
# 0  2609      4  499998
# 1  2238      3  329900
# 2  4478      5  699900
# 3  1962      4  259900
# 4  1600      3  329900

# %% [markdown]
# O/P : .head() shows the first five value of our DataFrame.

# %%
data.describe().T
# Out:
#        count           mean            std       min       25%       50%  \
# Area    47.0    2000.680851     794.702354     852.0    1432.0    1888.0
# Rooms   47.0       3.170213       0.760982       1.0       3.0       3.0
# Price   47.0  340412.659574  125039.899586  169900.0  249900.0  299900.0
#
#             75%       max
# Area     2269.0    4478.0
# Rooms       4.0       5.0
# Price  384450.0  699900.0

# %% [markdown]
# O/P : It gives Discriptive statistics and five number summary which includes count, mean, standard deviation, minimum value, 25 pecentile, 50 percentile, 75 percentile and maximum value

# %%
data.skew()
# Out:
# Area     1.358624
# Rooms   -0.300604
# Price    1.062284
# dtype: float64

# %%
sns.distplot(data['Area'])
# Out:
# C:\Users\DELL LAPPY\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Area', ylabel='Density'>

# %% [markdown]
# O/P : It shows the skewness of cloumn Area, And it Is +vely skewed.

# %%
sns.boxplot(data.Area)
# Out:
# C:\Users\DELL LAPPY\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Area'>

# %% [markdown]
# O/P : It shows visiualization of the five number summary of column Area of given DataFrame. And the dots shown represents
#       outlers.

# %%
sns.distplot(data['Rooms'])
# Out:
# C:\Users\DELL LAPPY\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rooms', ylabel='Density'>

# %% [markdown]
# O/P : It shows the skewness of cloumn Rooms, And it Is -vely skewed.

# %%
sns.boxplot(data.Rooms)
# Out:
# C:\Users\DELL LAPPY\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rooms'>

# %% [markdown]
# O/P : It shows visiualization of the five number summary of column Rooms of given DataFrame. And the dots shown represents
#       outlers.

# %%
sns.distplot(data['Price'])
# Out:
# C:\Users\DELL LAPPY\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# O/P : It shows the skewness of cloumn Price, And it Is +vely skewed.

# %%
sns.boxplot(data.Price)
# Out:
# C:\Users\DELL LAPPY\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# O/P : It shows visiualization of the five number summary of column price of given DataFrame. And the dots shown represents
#       outlers.

# %% [markdown]
# Here our EDA concludes. Now we will step forward with Linear Resgression and creating model using Linear Resgression.

# %%
x = data.drop('Price' , axis =1)
y = data['Price']

# %%
x
# Out:
#     Area  Rooms
# 0   2609      4
# 1   2238      3
# 2   4478      5
# 3   1962      4
# 4   1600      3
# 5   1268      3
# 6   3031      4
# 7   1664      2
# 8   1767      3
# 9   3137      3
# 10  4215      4
# 11  1888      2
# 0   2637      3
# 1   2132      4
# 2   1985      4
# 3   1416      2
# 4   2567      4
# 5   2162      4
# 6   1494      3
# 7   2000      3
# 8   2040      4
# 9   1000      1
# 10  1239      3
# 11  3000      4
# 12  2104      3
# 13  1437      3
# 14  1839      2
# 15  1852      4
# 16  1236      3
# 17  1100      3
# 18  1380      3
# 19  1940      4
# 20  1458      3
# 21  1427      3
# 22   852      2
# 23  1604      3
# 24  1811      4
# 25  2526      3
# 26  3890      3
# 27  1200      3
# 28  1534      3
# 29  2200      3
# 30  2300      4
# 31  1320      2
# 32  1890      3
# 33  1203      3
# 34  2400      3

# %%
x.reset_index(drop=True)
# Out:
#     Area  Rooms
# 0   2609      4
# 1   2238      3
# 2   4478      5
# 3   1962      4
# 4   1600      3
# 5   1268      3
# 6   3031      4
# 7   1664      2
# 8   1767      3
# 9   3137      3
# 10  4215      4
# 11  1888      2
# 12  2637      3
# 13  2132      4
# 14  1985      4
# 15  1416      2
# 16  2567      4
# 17  2162      4
# 18  1494      3
# 19  2000      3
# 20  2040      4
# 21  1000      1
# 22  1239      3
# 23  3000      4
# 24  2104      3
# 25  1437      3
# 26  1839      2
# 27  1852      4
# 28  1236      3
# 29  1100      3
# 30  1380      3
# 31  1940      4
# 32  1458      3
# 33  1427      3
# 34   852      2
# 35  1604      3
# 36  1811      4
# 37  2526      3
# 38  3890      3
# 39  1200      3
# 40  1534      3
# 41  2200      3
# 42  2300      4
# 43  1320      2
# 44  1890      3
# 45  1203      3
# 46  2400      3

# %%
y
# Out:
# 0     499998
# 1     329900
# 2     699900
# 3     259900
# 4     329900
# 5     259900
# 6     599000
# 7     368500
# 8     252900
# 9     579900
# 10    549000
# 11    255000
# 0     299900
# 1     345000
# 2     299900
# 3     232000
# 4     314000
# 5     287000
# 6     242500
# 7     347000
# 8     314900
# 9     169900
# 10    229900
# 11    539900
# 12    399900
# 13    249900
# 14    349900
# 15    299900
# 16    199900
# 17    249900
# 18    212000
# 19    239999
# 20    464500
# 21    198999
# 22    179900
# 23    242900
# 24    285900
# 25    469000
# 26    573900
# 27    299000
# 28    314900
# 29    475000
# 30    449900
# 31    299900
# 32    329999
# 33    239500
# 34    369000
# Name: Price, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (32, 2)
# (15, 2)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (32,)
# (15,)

# %%
#print(price_train.shape)
#print(price_test.shape)

# %%
x_train
# Out:
#     Area  Rooms
# 22   852      2
# 15  1852      4
# 9   1000      1
# 1   2132      4
# 26  3890      3
# 5   2162      4
# 30  2300      4
# 4   1600      3
# 16  1236      3
# 2   1985      4
# 10  4215      4
# 29  2200      3
# 18  1380      3
# 19  1940      4
# 28  1534      3
# 8   2040      4
# 6   1494      3
# 13  1437      3
# 6   3031      4
# 7   1664      2
# 32  1890      3
# 1   2238      3
# 4   2567      4
# 0   2609      4
# 3   1416      2
# 5   1268      3
# 11  1888      2
# 9   3137      3
# 8   1767      3
# 0   2637      3
# 31  1320      2
# 25  2526      3

# %%
x_test
# Out:
#     Area  Rooms
# 12  2104      3
# 10  1239      3
# 27  1200      3
# 23  1604      3
# 2   4478      5
# 3   1962      4
# 17  1100      3
# 20  1458      3
# 33  1203      3
# 14  1839      2
# 7   2000      3
# 24  1811      4
# 34  2400      3
# 21  1427      3
# 11  3000      4

# %%
x_test
# Out:
#     Area  Rooms
# 12  2104      3
# 10  1239      3
# 27  1200      3
# 23  1604      3
# 2   4478      5
# 3   1962      4
# 17  1100      3
# 20  1458      3
# 33  1203      3
# 14  1839      2
# 7   2000      3
# 24  1811      4
# 34  2400      3
# 21  1427      3
# 11  3000      4

# %%
y_train
# Out:
# 22    179900
# 15    299900
# 9     169900
# 1     345000
# 26    573900
# 5     287000
# 30    449900
# 4     329900
# 16    199900
# 2     299900
# 10    549000
# 29    475000
# 18    212000
# 19    239999
# 28    314900
# 8     314900
# 6     242500
# 13    249900
# 6     599000
# 7     368500
# 32    329999
# 1     329900
# 4     314000
# 0     499998
# 3     232000
# 5     259900
# 11    255000
# 9     579900
# 8     252900
# 0     299900
# 31    299900
# 25    469000
# Name: Price, dtype: int64

# %%
y_test
# Out:
# 12    399900
# 10    229900
# 27    299000
# 23    242900
# 2     699900
# 3     259900
# 17    249900
# 20    464500
# 33    239500
# 14    349900
# 7     347000
# 24    285900
# 34    369000
# 21    198999
# 11    539900
# Name: Price, dtype: int64

# %%
model1 = LinearRegression()

# %%
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_y = model1.predict(x_test)

# %%
pred_y
# Out:
# array([348511.06028195, 227791.20415849, 222348.34359339, 278730.79662677,
#        663302.72681814, 320430.95275458, 208392.29086235, 258354.95963946,
#        222767.02517532, 319790.03319401, 333996.76544167, 299357.31313072,
#        389820.97636582, 254028.58329284, 465294.78010273])

# %%
y_test.values.reshape(-1,1).flatten()
# Out:
# array([399900, 229900, 299000, 242900, 699900, 259900, 249900, 464500,
#        239500, 349900, 347000, 285900, 369000, 198999, 539900],
#       dtype=int64)

# %%
predicted_data = pd.DataFrame({'Actual_price':y_test, 'Predicted_price':pred_y})

# %%
predicted_data
# Out:
#     Actual_price  Predicted_price
# 12        399900    348511.060282
# 10        229900    227791.204158
# 27        299000    222348.343593
# 23        242900    278730.796627
# 2         699900    663302.726818
# 3         259900    320430.952755
# 17        249900    208392.290862
# 20        464500    258354.959639
# 33        239500    222767.025175
# 14        349900    319790.033194
# 7         347000    333996.765442
# 24        285900    299357.313131
# 34        369000    389820.976366
# 21        198999    254028.583293
# 11        539900    465294.780103

# %%
data1= pd.concat([x_test,predicted_data], axis=1)

# %%
predicted_data.shape
# Out:
# (15, 2)

# %%
data1
# Out:
#     Area  Rooms  Actual_price  Predicted_price
# 12  2104      3        399900    348511.060282
# 10  1239      3        229900    227791.204158
# 27  1200      3        299000    222348.343593
# 23  1604      3        242900    278730.796627
# 2   4478      5        699900    663302.726818
# 3   1962      4        259900    320430.952755
# 17  1100      3        249900    208392.290862
# 20  1458      3        464500    258354.959639
# 33  1203      3        239500    222767.025175
# 14  1839      2        349900    319790.033194
# 7   2000      3        347000    333996.765442
# 24  1811      4        285900    299357.313131
# 34  2400      3        369000    389820.976366
# 21  1427      3        198999    254028.583293
# 11  3000      4        539900    465294.780103

# %%
print(model1.coef_)
# Out:
# [  139.56052731 -8262.5126493 ]

# %% [markdown]
# It gives the coefficent of model that we have created i.e model1

# %%
print(model1.intercept_)
# Out:
# 79663.24876885983

# %% [markdown]
# It gives the Intercept of model1

# %% [markdown]
# Now creating Line of BestFit for model1

# %%
plt.scatter(x_test['Area'], y_test, color='yellow')
plt.plot(x_test['Area'], pred_y, color='black', linewidth=3)
plt.show()

# %% [markdown]
# Here, the line shown denote the line of bestfit which is clearly visible in black color, and the yellow color dots represents the data points

# %%
predicted_data.to_csv('Noorafshan_Assingment_1.csv')

# %% [markdown]
# This will save our created model in an .CSV file.
